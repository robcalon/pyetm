# %% [markdown]
# ### First Use Examples
# The ETMClient is the link between the ETM API and Python. In order to interact with a scenario, the ETMClient first needs to connect to a scenario in the ETM. The scenario to which the client is connected is referenced to with a scenario_id. There are several ways to connect to a scenario, you can create a new scenario, you can create a copy of existing scenario's or you can connect to an existing scenario. First time users probably want to create an entire new scenario or a scenario that is based on a predefined template.

# %%
from pyETM import Client

# use existing scenario to create a copy
template_id = "36950"
client = Client().from_existing_scenario(template_id)

# print scenario_id
scenario_id = client.scenario_id
scenario_id
# Out:
# '917922'

# %%
from pyETM import Client

# you can reconnect to your scenario with the provided scenario_id
client = Client(scenario_id)
client.scenario_id
# Out:
# '917922'

# %% [markdown]
# ### Scenario properties
# After a connection with a scenario is established, you can request specific properties of that given scenario. The more basic properties that can be accessed for example are the title, start year, end year and area code of the scenario.

# %%
client._get_scenario_header()
# Out:
# {'id': 917922,
#  'title': None,
#  'area_code': 'nl',
#  'start_year': 2015,
#  'end_year': 2050,
#  'description': None,
#  'url': 'https://engine.energytransitionmodel.com/api/v3/scenarios/917922',
#  'ordering': None,
#  'display_group': None,
#  'scaling': None,
#  'source': None,
#  'template': None,
#  'created_at': '2022-05-25T20:56:16.000Z',
#  'updated_at': '2022-05-25T20:56:16.000Z',
#  'read_only': False,
#  'protected': False,
#  'keep_compatible': False,
#  'esdl_exportable': None}

# %%
# set title of the scenario
client.title = 'Example scenario'
client.title
# Out:
# 'Example scenario'

# %% [markdown]
# More relevant properties of the scenario are the user configured parameters of the scenarios. You can access and change them via the user values property of the scenario.

# %%
# frst check which parameters can be set in the scenario
parameters = client.user_parameters
parameters.iloc[41:46]
# Out:
#                                                      min    max default unit  \
# efficiency_buildings_space_heater_crude_oil         70.0  100.0    85.0    %
# efficiency_buildings_space_heater_electricity       90.0  100.0   100.0    %
# efficiency_buildings_space_heater_heatpump_air_...   0.0  200.0   100.0    %
# efficiency_buildings_space_heater_hybrid_heatpu...   0.0  200.0   100.0    %
# efficiency_buildings_space_heater_network_gas       90.0  111.0   106.7    %
#
#                                                    cache_error user  disabled  \
# efficiency_buildings_space_heater_crude_oil                NaN  NaN     False
# efficiency_buildings_space_heater_electricity              NaN  NaN     False
# efficiency_buildings_space_heater_heatpump_air_...         NaN  NaN     False
# efficiency_buildings_space_heater_hybrid_heatpu...         NaN  NaN     False
# efficiency_buildings_space_heater_network_gas              NaN  NaN     False
#
#                                                    disabled_by share_group  \
# efficiency_buildings_space_heater_crude_oil                NaN         NaN
# efficiency_buildings_space_heater_electricity              NaN         NaN
# efficiency_buildings_space_heater_heatpump_air_...         NaN         NaN
# efficiency_buildings_space_heater_hybrid_heatpu...         NaN         NaN
# efficiency_buildings_space_heater_network_gas              NaN         NaN
#
#                                                    permitted_values
# efficiency_buildings_space_heater_crude_oil                     NaN
# efficiency_buildings_space_heater_electricity                   NaN
# efficiency_buildings_space_heater_heatpump_air_...              NaN
# efficiency_buildings_space_heater_hybrid_heatpu...              NaN
# efficiency_buildings_space_heater_network_gas                   NaN

# %%
# show parameters that are set by the user
client.user_values
# Out:
# Series([], Name: user, dtype: object)

# %%
# let's the capacities of several plants
# we can specify these changes in a dictonairy or series object.
user_values = {
    'capacity_of_energy_power_nuclear_gen2_uranium_oxide' : 750,
    'capacity_of_energy_power_wind_turbine_coastal' : 1500,
    'capacity_of_energy_power_wind_turbine_offshore' : 500
}

# apply the changes to the scenario
client.user_values = user_values
client.user_values
# Out:
# capacity_of_energy_power_nuclear_gen2_uranium_oxide     750.0
# capacity_of_energy_power_wind_turbine_coastal          1500.0
# capacity_of_energy_power_wind_turbine_offshore          500.0
# Name: user, dtype: object

# %% [markdown]
# As the user_values can be passed in different formats, it is possible to load a json as a dictonairy or a csv-file as series or dataframe with a 'user' column. When parameters are passed with a value outside the domain that is specified, the client will raise an error.
#
# ### Result Curves
# Simular to the scenario properties, the results of a scenario can also be accessed as properties of the scenario. When scenario parameters are changed, all results curves are automatically reset and are requested again upon accessing the client property. This means that the first time that a result curve is requested some time will pass before the result is loaded, as the ETM is evaluating the scenario in the background.

# %%
# request hourly electricity curves
ecurves = client.hourly_electricity_curves
ecurves.head()
# Out:
#                      buildings_solar_pv_solar_radiation.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                             0.0
# 2050-01-01 01:00:00                                             0.0
# 2050-01-01 02:00:00                                             0.0
# 2050-01-01 03:00:00                                             0.0
# 2050-01-01 04:00:00                                             0.0
#
#                      energy_battery_solar_pv_solar_radiation.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                                0.0
# 2050-01-01 01:00:00                                                0.0
# 2050-01-01 02:00:00                                                0.0
# 2050-01-01 03:00:00                                                0.0
# 2050-01-01 04:00:00                                                0.0
#
#                      energy_battery_wind_turbine_inland.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                             0.0
# 2050-01-01 01:00:00                                             0.0
# 2050-01-01 02:00:00                                             0.0
# 2050-01-01 03:00:00                                             0.0
# 2050-01-01 04:00:00                                             0.0
#
#                      energy_chp_coal_gas.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                         116.7808
# 2050-01-01 01:00:00                         116.7808
# 2050-01-01 02:00:00                         116.7808
# 2050-01-01 03:00:00                         116.7808
# 2050-01-01 04:00:00                         116.7808
#
#                      energy_chp_combined_cycle_network_gas.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                           163.9717
# 2050-01-01 01:00:00                                           163.9717
# 2050-01-01 02:00:00                                           163.9717
# 2050-01-01 03:00:00                                           163.9717
# 2050-01-01 04:00:00                                           163.9717
#
#                      energy_chp_local_engine_biogas.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                    108.5708
# 2050-01-01 01:00:00                                    108.5708
# 2050-01-01 02:00:00                                    108.5708
# 2050-01-01 03:00:00                                    108.5708
# 2050-01-01 04:00:00                                    108.5708
#
#                      energy_chp_local_engine_network_gas.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                              0.0
# 2050-01-01 01:00:00                                              0.0
# 2050-01-01 02:00:00                                              0.0
# 2050-01-01 03:00:00                                              0.0
# 2050-01-01 04:00:00                                              0.0
#
#                      energy_chp_local_wood_pellets.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                    14.1025
# 2050-01-01 01:00:00                                    14.1025
# 2050-01-01 02:00:00                                    14.1025
# 2050-01-01 03:00:00                                    14.1025
# 2050-01-01 04:00:00                                    14.1025
#
#                      energy_chp_supercritical_ccs_waste_mix.output (MW)  \
# DateTime
# 2050-01-01 00:00:00                                                0.0
# 2050-01-01 01:00:00                                                0.0
# 2050-01-01 02:00:00                                                0.0
# 2050-01-01 03:00:00                                                0.0
# 2050-01-01 04:00:00                                                0.0
#
#                      energy_chp_supercritical_waste_mix.output (MW)  ...  \
# DateTime                                                             ...
# 2050-01-01 00:00:00                                          653.58  ...
# 2050-01-01 01:00:00                                          653.58  ...
# 2050-01-01 02:00:00                                          653.58  ...
# 2050-01-01 03:00:00                                          653.58  ...
# 2050-01-01 04:00:00                                          653.58  ...
#
#                      transport_bus_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                      0.6779
# 2050-01-01 01:00:00                                      0.5123
# 2050-01-01 02:00:00                                      0.4021
# 2050-01-01 03:00:00                                      0.3172
# 2050-01-01 04:00:00                                      0.2489
#
#                      transport_car_flexibility_p2p_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                                0.0
# 2050-01-01 01:00:00                                                0.0
# 2050-01-01 02:00:00                                                0.0
# 2050-01-01 03:00:00                                                0.0
# 2050-01-01 04:00:00                                                0.0
#
#                      transport_car_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                      7.0363
# 2050-01-01 01:00:00                                      2.6199
# 2050-01-01 02:00:00                                      1.2336
# 2050-01-01 03:00:00                                      0.8575
# 2050-01-01 04:00:00                                      0.8579
#
#                      transport_freight_train_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                            32.0425
# 2050-01-01 01:00:00                                            24.2145
# 2050-01-01 02:00:00                                            19.0064
# 2050-01-01 03:00:00                                            14.9908
# 2050-01-01 04:00:00                                            11.7668
#
#                      transport_motorcycle_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                             0.0134
# 2050-01-01 01:00:00                                             0.0050
# 2050-01-01 02:00:00                                             0.0024
# 2050-01-01 03:00:00                                             0.0016
# 2050-01-01 04:00:00                                             0.0016
#
#                      transport_passenger_train_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                            47.8428
# 2050-01-01 01:00:00                                            17.8140
# 2050-01-01 02:00:00                                             8.3876
# 2050-01-01 03:00:00                                             5.8308
# 2050-01-01 04:00:00                                             5.8334
#
#                      transport_tram_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                       6.6211
# 2050-01-01 01:00:00                                       2.4653
# 2050-01-01 02:00:00                                       1.1608
# 2050-01-01 03:00:00                                       0.8069
# 2050-01-01 04:00:00                                       0.8073
#
#                      transport_truck_using_electricity.input (MW)  \
# DateTime
# 2050-01-01 00:00:00                                        0.2004
# 2050-01-01 01:00:00                                        0.1514
# 2050-01-01 02:00:00                                        0.1189
# 2050-01-01 03:00:00                                        0.0938
# 2050-01-01 04:00:00                                        0.0736
#
#                      transport_van_using_electricity.input (MW)  deficit
# DateTime
# 2050-01-01 00:00:00                                      0.3392      0.0
# 2050-01-01 01:00:00                                      0.2563      0.0
# 2050-01-01 02:00:00                                      0.2012      0.0
# 2050-01-01 03:00:00                                      0.1587      0.0
# 2050-01-01 04:00:00                                      0.1246      0.0
#
# [5 rows x 195 columns]

# %% [markdown]
# ### Custom Curves
# It is also possible to upload custom curves for a select number of parameters.

# %%
# show if there are custom curves attached in the scenario
client.ccurves.attached
# Out:
# key
# interconnector_1_price              False
# interconnector_2_price              False
# interconnector_3_price              False
# interconnector_4_price              False
# interconnector_5_price              False
# interconnector_6_price              False
# weather/buildings_heating           False
# electric_buses                      False
# electric_trucks                     False
# electric_vehicle_profile_1          False
# electric_vehicle_profile_2          False
# electric_vehicle_profile_3          False
# electric_vehicle_profile_4          False
# electric_vehicle_profile_5          False
# industry_chemicals_electricity      False
# industry_chemicals_heat             False
# industry_fertilizers_electricity    False
# industry_fertilizers_heat           False
# industry_ict                        False
# industry_metals_electricity         False
# industry_metals_heat                False
# industry_other_electricity          False
# industry_other_heat                 False
# industry_refineries_electricity     False
# industry_refineries_heat            False
# hydrogen_export                     False
# hydrogen_import                     False
# network_gas_export                  False
# network_gas_import                  False
# weather/solar_pv_profile_1          False
# weather/solar_thermal               False
# geothermal_heat                     False
# river                               False
# weather/wind_offshore_baseline      False
# weather/wind_coastal_baseline       False
# weather/wind_inland_baseline        False
# Name: attached, dtype: bool

# %% [markdown]
# Set some scenarios by passing random data for the interconnectors

# %%
import numpy as np
import pandas as pd

# create prices for interconnectors
con1 = pd.Series(np.random.rand(8760)*3, name='interconnector_1_price')
con2 = pd.Series(np.random.rand(8760)*49, name='interconnector_2_price')
con3 = pd.Series(np.random.rand(8760)*5, name='interconnector_3_price')

# create capacity factors for wind
offshore = pd.Series(np.random.rand(8760), name='weather/wind_offshore_baseline')
onshore = pd.Series(np.random.rand(8760), name='weather/wind_inland_baseline')

# merge series in dataframe
ccurves = pd.concat([con1, con2, offshore, onshore], axis=1)

# show random data
ccurves.head()
# Out:
#    interconnector_1_price  interconnector_2_price  \
# 0                1.809647                8.196088
# 1                2.354015               31.422294
# 2                1.710784               35.427180
# 3                0.537753               48.010908
# 4                1.985505               47.258131
#
#    weather/wind_offshore_baseline  weather/wind_inland_baseline
# 0                        0.175538                      0.343581
# 1                        0.659629                      0.181104
# 2                        0.111855                      0.959938
# 3                        0.750566                      0.923117
# 4                        0.506963                      0.934237

# %%
# set data as ccurves profiles and specify dataset
client.upload_custom_curves(ccurves, name='DataFrame upload')

# this also works for individual series
client.upload_custom_curve(con3, name='Series upload')

# show uploaded ccurves
curves = client.ccurves()
curves = curves[curves.attached == True]

# show ccurves
curves
# Out:
#                                             type           display_group  \
# key
# interconnector_1_price                     price         interconnectors
# interconnector_2_price                     price         interconnectors
# interconnector_3_price                     price         interconnectors
# weather/wind_offshore_baseline  capacity_profile  electricity_production
# weather/wind_inland_baseline    capacity_profile  electricity_production
#
#                                 attached  overrides              name  \
# key
# interconnector_1_price              True          1  DataFrame upload
# interconnector_2_price              True          1  DataFrame upload
# interconnector_3_price              True          1     Series upload
# weather/wind_offshore_baseline      True          2  DataFrame upload
# weather/wind_inland_baseline        True          2  DataFrame upload
#
#                                     size                  datetime  \
# key
# interconnector_1_price           42950.0 2022-05-25 20:56:24+00:00
# interconnector_2_price           49869.0 2022-05-25 20:56:24+00:00
# interconnector_3_price           42969.0 2022-05-25 20:56:25+00:00
# weather/wind_offshore_baseline  195821.0 2022-05-25 20:56:24+00:00
# weather/wind_inland_baseline    195829.0 2022-05-25 20:56:25+00:00
#
#                                source_scenario
# key
# interconnector_1_price                      {}
# interconnector_2_price                      {}
# interconnector_3_price                      {}
# weather/wind_offshore_baseline             NaN
# weather/wind_inland_baseline               NaN
